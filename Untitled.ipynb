# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vgsales_5.csv')
df
# Out:
#       Rank                                           Name Platform    Year  \
# 0    12643    The History Channel: Battle for the Pacific     X360  2007.0
# 1    10134              Yu Yu Hakusho: Tournament Tactics      GBA  2004.0
# 2     9490  The History Channel: Great Battles - Medieval     X360  2010.0
# 3     2052                                Monster Rancher       PS  1997.0
# 4     9266                       Singstar: Ultimate Party      PS3  2014.0
# ..     ...                                            ...      ...     ...
# 548   9510                                     Last Bronx      SAT  1996.0
# 549  14523                    Star Trek: Tactical Assault      PSP  2006.0
# 550   7811             IHRA Professional Drag Racing 2005      PS2  2004.0
# 551   5215                        AMF Bowling World Lanes      Wii  2008.0
# 552  12012                      Point Blank DS (JP sales)       DS  2006.0
#
# ...

# %%
df.head(10)
# Out:
#     Rank                                           Name Platform    Year  \
# 0  12643    The History Channel: Battle for the Pacific     X360  2007.0
# 1  10134              Yu Yu Hakusho: Tournament Tactics      GBA  2004.0
# 2   9490  The History Channel: Great Battles - Medieval     X360  2010.0
# 3   2052                                Monster Rancher       PS  1997.0
# 4   9266                       Singstar: Ultimate Party      PS3  2014.0
# 5    553                             Onimusha: Warlords      PS2  2001.0
# 6  16184                           Resistance Dual Pack      PS3  2011.0
# 7  12718                                    Titan Quest       PC  2006.0
# 8   1562                                  Hogan's Alley      NES  1984.0
# 9   7948                              Star Trek: Legacy     X360     NaN
#
#           Genre                           Publisher  NA_Sales  EU_Sales  \
# 0       Shooter                          Activision      0.05      0.00
# ...

# %%
df.describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales  \
# count    553.000000   542.000000  553.000000  553.000000  553.000000
# mean    8192.810127  2006.335793    0.242441    0.121284    0.068879
# std     4736.853364     5.867433    0.614151    0.294055    0.212344
# min       30.000000  1981.000000    0.000000    0.000000    0.000000
# 25%     3938.000000  2003.000000    0.000000    0.000000    0.000000
# 50%     8188.000000  2007.000000    0.080000    0.030000    0.000000
# 75%    12241.000000  2010.000000    0.250000    0.130000    0.030000
# max    16503.000000  2016.000000    9.030000    4.280000    2.350000
#
#        Other_Sales  Global_Sales
# count   553.000000    553.000000
# mean      0.057034      0.489910
# std       0.338951      1.120093
# min       0.000000      0.010000
# 25%       0.000000      0.070000
# 50%       0.010000      0.180000
# 75%       0.040000      0.510000
# max       7.530000     14.760000

# %%
df.count()
# Out:
# Rank            553
# Name            553
# Platform        553
# Year            542
# Genre           553
# Publisher       553
# NA_Sales        553
# EU_Sales        553
# JP_Sales        553
# Other_Sales     553
# Global_Sales    553
# dtype: int64

# %%
df.where(df['Rank'] == 30).dropna()
df.where(df['Rank'] == 16503).dropna()
# Out:
#         Rank                              Name Platform    Year      Genre  \
# 504  16503.0  Satomi Hakkenden: Hachi Tamanoki      PSP  2014.0  Adventure
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 504  Quinrose       0.0       0.0      0.01          0.0          0.01

# %%
print("Вывод уникальных наименований игр: ", len(df.Name.unique()))
print('')
print('Наименования: ', df.Name.unique())
# Out:
# Вывод уникальных наименований игр:  532
#
# Наименования:  ['The History Channel: Battle for the Pacific'
#  'Yu Yu Hakusho: Tournament Tactics'
#  'The History Channel: Great Battles - Medieval' 'Monster Rancher'
#  'Singstar: Ultimate Party' 'Onimusha: Warlords' 'Resistance Dual Pack'
#  'Titan Quest' "Hogan's Alley" 'Star Trek: Legacy' 'NEVES' 'Reactor'
#  'Crash: Twinsanity' 'Hamtaro: Ham-Hams Unite!'
#  'LEGO Indiana Jones: The Original Adventures'
#  'Metal Gear Solid: Portable Ops Plus'
#  'Secret Service: Ultimate Sacrifice'
#  'My SAT Coach with The Princeton Review' 'Last Escort: Club Katze'
#  'I-Ninja' 'The Next Tetris' 'Impact Racing' 'Beyond the Labyrinth'
#  'Monster Trux Arenas: Special Edition' 'Dance Central 2'
#  'Digging for Dinosaurs' 'Watch Dogs' 'RoadKill'
#  'IHRA Drag Racing: Sportsman Edition' 'Space Bust-A-Move'
#  'Rock Band Country Track Pack 2'
#  'King of Fighters: Maximum Impact Regulation A' 'James Bond 007: Legends'
# ...

# %%
print('Процент уникальных значений: ', len(df.Name.unique()) / len(df) * 100, "%")
# Out:
# Процент уникальных значений:  96.20253164556962 %

# %%
print('Процент неуникальных значений: ', 100 - len(df.Name.unique()) / len(df) * 100, "%")
# Out:
# Процент неуникальных значений:  3.7974683544303787 %

# %%
publisher = df.groupby(['Publisher', 'Year'])['Name'].value_counts()
print("Игры выпущеныые несколько раз одним и тем же издателем", publisher.where(publisher > 1).dropna())
# Out:
# Игры выпущеныые несколько раз одним и тем же издателем Publisher                               Year    Name
# Activision                              2008.0  007: Quantum of Solace                                                2.0
#                                         2009.0  Transformers: Revenge of the Fallen (XBox 360, PS3, & PC Versions)    2.0
# Codemasters                             2011.0  F1 2011                                                               2.0
# Electronic Arts                         2009.0  Madden NFL 10                                                         2.0
#                                         2016.0  FIFA 17                                                               2.0
# Global Star                             2004.0  Scaler                                                                2.0
# Konami Digital Entertainment            2002.0  Disney Sports Skateboarding                                           2.0
# ...

# %%
df.loc[df['Name'] == 'RoadKill']
# Out:
#       Rank      Name Platform    Year   Genre     Publisher  NA_Sales  \
# 27   11557  RoadKill       XB  2003.0  Action  Midway Games      0.06
# 412  11557  RoadKill       XB  2003.0  Action  Midway Games      0.06
# 510  11557  RoadKill       XB  2003.0  Action  Midway Games      0.06
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 27       0.02       0.0          0.0          0.08
# 412      0.02       0.0          0.0          0.08
# 510      0.02       0.0          0.0          0.08

# %%
print('Количество уникальных платформ: ', len(df['Platform'].unique()))
#print('Наименование уникальных платформ: \n', df['Platform'].unique())
print('Наименование уникальных платформ: ', df['Platform'].value_counts())
# Out:
# Количество уникальных платформ:  24
# Наименование уникальных платформ:  PS2     71
# DS      61
# X360    52
# PS3     52
# PC      40
# PS      38
# PSP     33
# Wii     33
# XB      28
# GBA     28
# 3DS     19
# GC      18
# PSV     17
# N64     11
# PS4     10
# SNES    10
# XOne     8
# NES      5
# WiiU     5
# DC       4
# SAT      4
# 2600     3
# GB       2
# GEN      1
# Name: Platform, dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Rank            0.00000
# Name            0.00000
# Platform        0.00000
# Year            1.98915
# Genre           0.00000
# Publisher       0.00000
# NA_Sales        0.00000
# EU_Sales        0.00000
# JP_Sales        0.00000
# Other_Sales     0.00000
# Global_Sales    0.00000
# dtype: float64

# %%
df = df.drop_duplicates(subset=['Name', 'Platform'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          544 non-null    int64
#  1   Name          544 non-null    object
#  2   Platform      544 non-null    object
#  3   Year          533 non-null    float64
#  4   Genre         544 non-null    object
#  5   Publisher     544 non-null    object
#  6   NA_Sales      544 non-null    float64
#  7   EU_Sales      544 non-null    float64
#  8   JP_Sales      544 non-null    float64
#  9   Other_Sales   544 non-null    float64
#  10  Global_Sales  544 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 51.0+ KB

# %%
p5 = pd.DataFrame([
    [1,1,1, ''],
    [1,1,1, ''],
    [1,1,1, '']],
    columns = ['id', 'Name', 'age', 'Genre'])
p5
# Out:
#    id  Name  age Genre
# 0   1     1    1
# 1   1     1    1
# 2   1     1    1

# %%
p5.drop(columns = ['Genre'])
# Out:
#    id  Name  age
# 0   1     1    1
# 1   1     1    1
# 2   1     1    1

# %%
p5_vers = pd.DataFrame([
    [1,1,1, np.nan],
    [1,1,1, np.nan],
    [1,1,1, 1]],
    columns = ['id', 'Name', 'age', 'Genre'])
p5_vers
# Out:
#    id  Name  age  Genre
# 0   1     1    1    NaN
# 1   1     1    1    NaN
# 2   1     1    1    1.0

# %%
p5_vers = p5_vers.dropna(subset=['Genre'])
p5_vers
# Out:
#    id  Name  age  Genre
# 2   1     1    1    1.0

# %%
p5_vers = p5_vers.replace({'Genre': np.nan}, 'N/A')
p5_vers
# Out:
#    id  Name  age Genre
# 0   1     1    1   N/A
# 1   1     1    1   N/A
# 2   1     1    1   1.0

# %%
from sklearn.impute import SimpleImputer

simp = SimpleImputer(strategy = 'mean', missing_values = np.nan)
simp = simp.fit(df[['Year']])
df['Year'] = simp.transform(df[['Year']])

df.isnull().mean()*100
# Out:
# Rank            0.0
# Name            0.0
# Platform        0.0
# Year            0.0
# Genre           0.0
# Publisher       0.0
# NA_Sales        0.0
# EU_Sales        0.0
# JP_Sales        0.0
# Other_Sales     0.0
# Global_Sales    0.0
# dtype: float64

# %%
df.to_csv('vgsales_P5.csv', index=False)
df = pd.read_csv('vgsales_P5.csv')
df
# Out:
#       Rank                                           Name Platform    Year  \
# 0    12643    The History Channel: Battle for the Pacific     X360  2007.0
# 1    10134              Yu Yu Hakusho: Tournament Tactics      GBA  2004.0
# 2     9490  The History Channel: Great Battles - Medieval     X360  2010.0
# 3     2052                                Monster Rancher       PS  1997.0
# 4     9266                       Singstar: Ultimate Party      PS3  2014.0
# ..     ...                                            ...      ...     ...
# 548   9510                                     Last Bronx      SAT  1996.0
# 549  14523                    Star Trek: Tactical Assault      PSP  2006.0
# 550   7811             IHRA Professional Drag Racing 2005      PS2  2004.0
# 551   5215                        AMF Bowling World Lanes      Wii  2008.0
# 552  12012                      Point Blank DS (JP sales)       DS  2006.0
#
# ...
